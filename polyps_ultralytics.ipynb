# %% [markdown]
# <a href="https://colab.research.google.com/github/is1079642/VIT2/blob/main/polyps_ultralytics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!git clone https://github.com/ultralytics/yolov5  # clone
#!git clone https://github.com/ultralytics/ultralytics  # clone
#%cd ultralytics
#%pip install -qr requirements.txt  # install

#import torch
#import utils
#display = utils.notebook_init()  # checks

# %pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 606.6/606.6 kB 8.5 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
import os
os.chdir('/content/drive/MyDrive/data')
# Out:
# Mounted at /content/drive

# %%
#!python /content/yolov5/train.py --img 640 --batch 14 --epochs 10 --data /content/drive/MyDrive/data/dataset/polyps/polyps.yaml --weights yolov5x.pt --cache

#Detección
#_--------------------------------
# Load a model
from ultralytics import YOLO
model = YOLO("yolov8n.yaml")  # build a new model from scratch
model = YOLO("yolov8n.pt")  # load a pretrained model (recommended for training)

# Use the model
model.train(data="/content/drive/MyDrive/data/dataset/polyps/polyps.yaml", epochs=50)  # train the model
metrics = model.val()  # evaluate model performance on the validation set


#path = model.export(format="onnx")  # export the model to ONNX format
#----------------------------------
#Clasificación
#from ultralytics import YOLO

# Load a model
#model = YOLO('yolov8n-cls.yaml')  # build a new model from YAML
#model = YOLO('yolov8n-cls.pt')  # load a pretrained model (recommended for training)
#model = YOLO('yolov8n-cls.yaml').load('yolov8n-cls.pt')  # build from YAML and transfer weights

# Train the model
#model.train(data='mnist160', epochs=100, imgsz=64)
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
# ...

# %%
results = model("/content/17033.jpg", save=True)  # predict on an image
# Out:
# image 1/1 /content/17033.jpg: 480x640 1 adenomatoso, 102.9ms
# Speed: 4.0ms preprocess, 102.9ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs/detect/predict12

# %%
#Valida el Modelo
from ultralytics import YOLO

# Load a model
model = YOLO('yolov8n-cls.pt')  # load an official model
model = YOLO('/content/drive/MyDrive/data/runs/classify/train/weights/best.pt')  # load a custom model

# Validate the model
metrics = model.val()  # no arguments needed, dataset and settings remembered
metrics.top1   # top1 accuracy
metrics.top5   # top5 accuracy
# Out:
# Ultralytics YOLOv8.0.140 🚀 Python-3.10.6 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n-cls summary (fused): 73 layers, 1447690 parameters, 0 gradients
# WARNING ⚠️ Dataset 'split=val' not found, using 'split=test' instead.
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:00<00:00,  7.31it/s]
#                    all        0.9      0.988
# Speed: 0.5ms preprocess, 6.0ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to runs/classify/val
# 0.987500011920929

# %%
#Predice
from ultralytics import YOLO

# Load a model
model = YOLO('yolov8n-cls.pt')  # load an official model
model = YOLO('/content/drive/MyDrive/data/runs/classify/train/weights/best.pt')  # load a custom model

# Predict with the model
results = model('https://ultralytics.com/images/bus.jpg',save=True, save_crop=True, hide_labels=false)  # predict on an image
# Out:
# WARNING ⚠️ 'hide_labels' is deprecated and will be removed in 'ultralytics 8.2' in the future. Please use 'show_labels' instead.
#
# Found https://ultralytics.com/images/bus.jpg locally at bus.jpg
# WARNING ⚠️ Classify task do not support `save_crop`.
# image 1/1 /content/drive/MyDrive/data/bus.jpg: 64x64 4 0.16, 1 0.14, 9 0.12, 0 0.11, 2 0.11, 2.7ms
# Speed: 0.5ms preprocess, 2.7ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
# Results saved to runs/classify/predict4

# %%
# !yes | ffmpeg -ss 00:00:00 -i /content/video2.avi -t 4 -vf fps=80 out.avi
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...

# %%
# !python /content/yolov5/detect.py --weights /content/yolov5/runs/train/exp/weights/best.pt --img 640 --conf 0.25 --source "/content/video4.avi"
# Out:
# WARNING ⚠️ 'ultralytics.yolo.v8' is deprecated since '8.0.136' and will be removed in '8.1.0'. Please use 'ultralytics.models.yolo' instead.
# WARNING ⚠️ 'ultralytics.yolo.utils' is deprecated since '8.0.136' and will be removed in '8.1.0'. Please use 'ultralytics.utils' instead.
# Note this warning may be related to loading older models. You can update your model to current structure with:
#     import torch
#     ckpt = torch.load("model.pt")  # applies to both official and custom models
#     torch.save(ckpt, "updated-model.pt")
#
# ...
